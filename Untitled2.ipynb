# %% [markdown]
# <a href="https://colab.research.google.com/github/aaraadhyaVanama/Asteriod-Hazard-Prediction-Model/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("neo_dur_df.csv")
print("read the file")
# Out:
# read the file

# %%
df.head()
# Out:
#    Unnamed: 0       id  orbit_id orbit_determination_date  \
# 0           0  2000433       659      2021-05-24 17:55:05
# 1           1  2000719       272      2025-03-28 06:20:45
# 2           2  2001036      1392      2025-04-29 06:20:34
# 3           3  2001221       143      2025-02-20 05:51:07
# 4           4  2001566       194      2025-08-19 08:22:05
#
#   first_observation_date last_observation_date  data_arc_in_days  \
# 0             1893-10-29            2021-05-13           46582.0
# 1             1911-10-04            2025-03-28           41449.0
# 2             1924-10-23            2025-04-18           36702.0
# 3             1932-03-12            2025-02-19           33947.0
# 4             1949-07-01            2025-08-18           27807.0
#
#    observations_used  orbit_uncertainty  minimum_orbit_intersection  ...  \
# 0               9130                  0                    0.148353  ...
# 1               2102                  0                    0.201318  ...
# ...
